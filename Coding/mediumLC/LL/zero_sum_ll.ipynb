# %%
"""
Given the head of a linked list, we repeatedly delete consecutive sequences of nodes that sum to 0 until there are no such sequences.

After doing so, return the head of the final linked list.  You may return any such answer.

 

(Note that in the examples below, all sequences are serializations of ListNode objects.)

Example 1:

Input: head = [1,2,-3,3,1]
Output: [3,1]
Note: The answer [1,2,1] would also be accepted.
Example 2:

Input: head = [1,2,3,-3,4]
Output: [1,2,4]
Example 3:

Input: head = [1,2,3,-3,-2]
Output: [1]
 

Constraints:

The given linked list will contain between 1 and 1000 nodes.
Each node in the linked list has -1000 <= node.val <= 1000.
"""

# Definition for singly-linked list.

from collections import OrderedDict as OD

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def removeZeroSumSublists(self, head):
        start = ListNode(0)
        seen = OD([(0, start)])
        prevh = 0
        curr = head
        while curr:
            if curr.val == 0:
                curr = curr.next
                continue
            currh = prevh + curr.val
            if currh in seen:
                tot_sum = curr.val
                while seen and tot_sum != 0:
                    tot_sum += seen.popitem()[1].val
            else:
                seen[currh] = curr
            curr = curr.next
            prevh = currh
        nodes = list(seen.values()) + [None]
        for idx, node in enumerate(nodes[1:]):
            nodes[idx].next = node
        return start.next

# %%
class Solution:
    def removeZeroSumSublists(self, head):
        start = ListNode(0)
        seen = OD([(0, start)])
        prevh = 0
        curr = head
        while curr:
            if curr.val == 0:
                curr = curr.next
                continue
            currh = prevh + curr.val
            last = curr
            if currh in seen:
                popped = None
                last = seen[currh]
                while popped != last:
                    popped = seen.popitem()[1]
            seen[currh] = last
            curr = curr.next
            prevh = currh
        nodes = list(seen.values()) + [None]
        for idx, node in enumerate(nodes[1:]):
            nodes[idx].next = node
        return start.next
